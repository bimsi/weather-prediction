# %% [markdown]
# <a href="https://colab.research.google.com/github/bimsi/weather-prediction/blob/main/weather_yt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a5c2eadd-9769-4df4-b1a9-251ff905e561" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a5c2eadd-9769-4df4-b1a9-251ff905e561">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
weather = pd.read_csv("/content/local_weather.csv", index_col = 'DATE')

# %%
weather
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# ...                 ...                                   ...   ...   ...
# 2022-01-24  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-25  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-26  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-27  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 2022-01-28  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
# ...

# %%
missing_percent = weather.apply(pd.isnull)
missing_percent
# Out:
#             STATION   NAME  ACMH  ACSH   AWND  DAPR  FMTM  FRGT  MDPR   PGTM  \
# DATE
# 1960-01-01    False  False  True  True   True  True  True  True  True   True
# 1960-01-02    False  False  True  True   True  True  True  True  True   True
# 1960-01-03    False  False  True  True   True  True  True  True  True   True
# 1960-01-04    False  False  True  True   True  True  True  True  True   True
# 1960-01-05    False  False  True  True   True  True  True  True  True   True
# ...             ...    ...   ...   ...    ...   ...   ...   ...   ...    ...
# 2022-01-24    False  False  True  True  False  True  True  True  True   True
# 2022-01-25    False  False  True  True  False  True  True  True  True   True
# 2022-01-26    False  False  True  True  False  True  True  True  True   True
# 2022-01-27    False  False  True  True  False  True  True  True  True  False
# 2022-01-28    False  False  True  True   True  True  True  True  True   True
#
# ...

# %%
missing_percent = weather.apply(pd.isnull).sum()
missing_percent
# Out:
# STATION        0
# NAME           0
# ACMH       11015
# ACSH       11015
# AWND        8808
# DAPR       16851
# FMTM       14669
# FRGT       16857
# MDPR       16851
# PGTM        8347
# PRCP         281
# SNOW        5479
# SNWD        5355
# TAVG       14822
# TMAX           9
# TMIN          10
# TSUN       15708
# WDF1       11015
# WDF2        8807
# WDF5        8894
# WDFG       12592
# WSF1       11015
# WSF2        8806
# WSF5        8894
# WSFG       12592
# WT01       13149
# WT02       16526
# WT03       16740
# WT04       16855
# WT05       16831
# WT07       16857
# WT08       13662
# WT09       16857
# WT16       14904
# WT18       16856
# dtype: int64

# %%
missing_percent = weather.apply(pd.isnull).shape[0]
missing_percent
# Out:
# 16859

# %%
missing_percent = weather.apply(pd.isnull).sum()/weather.shape[0]
missing_percent
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.653360
# ACSH       0.653360
# AWND       0.522451
# DAPR       0.999525
# FMTM       0.870099
# FRGT       0.999881
# MDPR       0.999525
# PGTM       0.495106
# PRCP       0.016668
# SNOW       0.324990
# SNWD       0.317634
# TAVG       0.879174
# TMAX       0.000534
# TMIN       0.000593
# TSUN       0.931728
# WDF1       0.653360
# WDF2       0.522392
# WDF5       0.527552
# WDFG       0.746901
# WSF1       0.653360
# WSF2       0.522332
# WSF5       0.527552
# WSFG       0.746901
# WT01       0.779939
# WT02       0.980248
# WT03       0.992941
# WT04       0.999763
# WT05       0.998339
# WT07       0.999881
# WT08       0.810368
# WT09       0.999881
# WT16       0.884038
# WT18       0.999822
# dtype: float64
